# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install plotly
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

import warnings
warnings.filterwarnings('ignore')

plt.style.use('fivethirtyeight')
# %matplotlib inline
pd.set_option('display.max_columns', 26)

# %%
df= pd.read_csv('chronic.csv')
df.head()
# Out:
#   YearStart  YearEnd LocationAbbr    LocationDesc DataSource  \
# 0      2010   2010.0           OR          Oregon       NVSS
# 1      2019   2019.0           AZ         Arizona      YRBSS
# 2      2019   2019.0           OH            Ohio      YRBSS
# 3      2019   2019.0           US   United States      YRBSS
# 4      2015   2015.0           VI  Virgin Islands      YRBSS
#
#                     Topic                      Question  \
# 0  Cardiovascular Disease  Mortality from heart failure
# 1                 Alcohol       Alcohol use among youth
# 2                 Alcohol       Alcohol use among youth
# 3                 Alcohol       Alcohol use among youth
# 4                 Alcohol       Alcohol use among youth
#
#                                             Response DataValueUnit  \
# 0  According to the National Vital Statistics Sys...           NaN
# 1  According to the Youth Risk Behavior Surveilla...             %
# ...

# %%
df.shape
# Out:
# (29, 28)

# %%
df.drop('DataValueAlt', axis = 1, inplace = True)

# %%
df.head()
# Out:
#   YearStart  YearEnd LocationAbbr    LocationDesc DataSource  \
# 0      2010   2010.0           OR          Oregon       NVSS
# 1      2019   2019.0           AZ         Arizona      YRBSS
# 2      2019   2019.0           OH            Ohio      YRBSS
# 3      2019   2019.0           US   United States      YRBSS
# 4      2015   2015.0           VI  Virgin Islands      YRBSS
#
#                     Topic                      Question  \
# 0  Cardiovascular Disease  Mortality from heart failure
# 1                 Alcohol       Alcohol use among youth
# 2                 Alcohol       Alcohol use among youth
# 3                 Alcohol       Alcohol use among youth
# 4                 Alcohol       Alcohol use among youth
#
#                                             Response DataValueUnit  \
# 0  According to the National Vital Statistics Sys...           NaN
# 1  According to the Youth Risk Behavior Surveilla...             %
# ...

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv('chronic.csv')

# Display the column names to confirm the number of columns
print("Original columns:", df.columns)

# Rename specific columns using the `rename` method
df.rename(columns={'Topic': 'question', 'Question': 'response'}, inplace=True)

# Display the updated column names
print("Updated columns:", df.columns)
# Out:
# Original columns: Index(['YearStart', 'YearEnd', 'LocationAbbr', 'LocationDesc', 'DataSource',
#        'Topic', 'Question', 'Response', 'DataValueUnit', 'DataValueType',
#        'DataValue', 'DataValueAlt', 'DataValueFootnoteSymbol',
#        'DatavalueFootnote', 'LowConfidenceLimit', 'HighConfidenceLimit',
#        'StratificationCategory1', 'Stratification1', 'StratificationCategory2',
#        'Stratification2', 'StratificationCategory3', 'Stratification3',
#        'GeoLocation', 'ResponseID', 'LocationID', 'TopicID', 'QuestionID',
#        'DataValueTypeID'],
#       dtype='object')
# Updated columns: Index(['YearStart', 'YearEnd', 'LocationAbbr', 'LocationDesc', 'DataSource',
#        'question', 'response', 'Response', 'DataValueUnit', 'DataValueType',
#        'DataValue', 'DataValueAlt', 'DataValueFootnoteSymbol',
#        'DatavalueFootnote', 'LowConfidenceLimit', 'HighConfidenceLimit',
#        'StratificationCategory1', 'Stratification1', 'StratificationCategory2',
# ...

# %%
df.describe()
# Out:
#            YearEnd  DataValue  DataValueAlt  LowConfidenceLimit  \
# count    19.000000  16.000000     16.000000           13.000000
# mean   2015.842105  50.950000     50.950000           44.523077
# std       3.354320  22.469654     22.469654           20.323556
# min    2010.000000  13.900000     13.900000           10.400000
# 25%    2013.000000  29.875000     29.875000           24.900000
# 50%    2016.000000  58.050000     58.050000           53.900000
# 75%    2019.000000  63.725000     63.725000           58.500000
# max    2020.000000  99.000000     99.000000           66.800000
#
#        HighConfidenceLimit  StratificationCategory2  Stratification2  \
# count            13.000000                      0.0              0.0
# mean             52.307692                      NaN              NaN
# std              18.833634                      NaN              NaN
# min              18.400000                      NaN              NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 28 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   YearStart                19 non-null     object
#  1   YearEnd                  19 non-null     float64
#  2   LocationAbbr             19 non-null     object
#  3   LocationDesc             19 non-null     object
#  4   DataSource               19 non-null     object
#  5   question                 19 non-null     object
#  6   response                 29 non-null     object
#  7   Response                 28 non-null     object
#  8   DataValueUnit            16 non-null     object
#  9   DataValueType            19 non-null     object
#  10  DataValue                16 non-null     float64
#  11  DataValueAlt             16 non-null     float64
#  12  DataValueFootnoteSymbol  3 non-null      object
#  13  DatavalueFootnote        3 non-null      object
# ...

# %%
cat_cols = [col for col in df.columns if df[col].dtype == 'object']
num_cols = [col for col in df.columns if df[col].dtype != 'object']

# %%
for col in cat_cols:
    print(f"{col} has {df[col].unique()} values\n")
# Out:
# YearStart has ['2010' '2019' '2015' '2020' '2018' 'Jul-05' '2011' '2012' '2013' '2016'
#  nan] values
#
# LocationAbbr has ['OR' 'AZ' 'OH' 'US' 'VI' 'AL' 'DE' 'FL' 'KS' 'MS' 'NJ' 'PA' 'SD' 'VT'
#  'AK' nan] values
#
# LocationDesc has ['Oregon' 'Arizona' 'Ohio' 'United States' 'Virgin Islands' 'Alabama'
#  'Delaware' 'Florida' 'Kansas' 'Mississippi' 'New Jersey' 'Pennsylvania'
#  'South Dakota' 'Vermont' 'Alaska' nan] values
#
# DataSource has ['NVSS' 'YRBSS' 'PRAMS' nan] values
#
# question has ['Cardiovascular Disease' 'Alcohol' nan] values
#
# response has ['Mortality from heart failure' 'Alcohol use among youth'
#  'Alcohol use before pregnancy' 'Binge drinking prevalence among youth'
#  'Chronic liver disease mortality' 'chronic disease' 'symptoms'
#  'treatment' 'lifestyle changes' 'medications' 'therapies'
#  'alternative therapies' 'surgical options' 'Disease-Specific Treatments'
#  'Ongoing Care'] values
#
# ...

# %%
plt.figure(figsize = (20, 15))
plotnumber = 1

for column in num_cols:
    if plotnumber <= 14:
        ax = plt.subplot(3, 5, plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column)
        
    plotnumber += 1

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize = (20, 15))
plotnumber = 1

for column in cat_cols:
    if plotnumber <= 11:
        ax = plt.subplot(3, 4, plotnumber)
        sns.countplot(df[column], palette = 'rocket')
        plt.xlabel(column)
        
    plotnumber += 1

plt.tight_layout()
plt.show()

# %%
df.columns
# Out:
# Index(['YearStart', 'YearEnd', 'LocationAbbr', 'LocationDesc', 'DataSource',
#        'question', 'response', 'Response', 'DataValueUnit', 'DataValueType',
#        'DataValue', 'DataValueAlt', 'DataValueFootnoteSymbol',
#        'DatavalueFootnote', 'LowConfidenceLimit', 'HighConfidenceLimit',
#        'StratificationCategory1', 'Stratification1', 'StratificationCategory2',
#        'Stratification2', 'StratificationCategory3', 'Stratification3',
#        'GeoLocation', 'ResponseID', 'LocationID', 'TopicID', 'QuestionID',
#        'DataValueTypeID'],
#       dtype='object')

# %%
def violin(col):
    fig = px.violin(df, y=col, x="class", color="class", box=True, template = 'plotly_dark')
    return fig.show()

def kde(col):
    grid = sns.FacetGrid(df, hue="class", height = 6, aspect=2)
    grid.map(sns.kdeplot, col)
    grid.add_legend()
    
def scatter(col1, col2):
    fig = px.scatter(df, x=col1, y=col2, color="class", template = 'plotly_dark')
    return fig.show()

# %%
df.isna().sum().sort_values(ascending = False)
# Out:
# StratificationCategory2    29
# StratificationCategory3    29
# Stratification2            29
# ResponseID                 29
# Stratification3            29
# DatavalueFootnote          26
# DataValueFootnoteSymbol    26
# HighConfidenceLimit        16
# LowConfidenceLimit         16
# DataValue                  13
# DataValueAlt               13
# GeoLocation                13
# DataValueUnit              13
# Stratification1            10
# LocationID                 10
# TopicID                    10
# QuestionID                 10
# YearStart                  10
# StratificationCategory1    10
# YearEnd                    10
# DataValueType              10
# question                   10
# DataSource                 10
# LocationDesc               10
# LocationAbbr               10
# DataValueTypeID            10
# Response                    1
# response                    0
# dtype: int64

# %%
df[num_cols].isnull().sum()
# Out:
# YearEnd                    10
# DataValue                  13
# DataValueAlt               13
# LowConfidenceLimit         16
# HighConfidenceLimit        16
# StratificationCategory2    29
# Stratification2            29
# StratificationCategory3    29
# Stratification3            29
# ResponseID                 29
# LocationID                 10
# dtype: int64
